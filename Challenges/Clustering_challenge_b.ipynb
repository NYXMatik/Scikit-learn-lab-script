# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.datasets import make_circles

# 1. Generate circle-shaped data
data, labels = make_circles(n_samples=300, noise=0.05, factor=0.5, random_state=42)

# 2. Plot raw generated data (single color)
plt.scatter(data[:, 0], data[:, 1], c='gray', marker='o', edgecolor='k')
plt.title("Generated Circles (Raw Data)")
plt.show()

# 3. Perform KMeans clustering with 2 clusters
kmeans = KMeans(n_clusters=5, random_state=42)
kmeans.fit(data)
predicted_labels = kmeans.labels_

# 4. Visualize the clustering results
plt.scatter(data[:, 0], data[:, 1], c=predicted_labels, cmap='viridis', marker='o', edgecolor='k')
plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], c='red', marker='x', s=200, label='Centroids')
plt.legend()
plt.title("KMeans Clustering on Circle-shaped Data")
plt.show()
